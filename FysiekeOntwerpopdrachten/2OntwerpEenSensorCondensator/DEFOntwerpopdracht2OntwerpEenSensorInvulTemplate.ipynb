# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: 6    |  |
# | :-------------|:-------------|
# | Tobias van Bavel| 6436404 |
# | Wouter Zeilmaker| 6585043 |
# | Job Kruisdijk| 6278108 |
# | Planning Groep: 6    |Tijdstip / Tijdspanne  |
# |---|---|
# |sanity check 1 en 2| 11:30|
# | condensator gedeelte af | 12:45 |
# |opdracht synthesse|14:30|
# |simulatie af|16:00|
# | sensor af | 17:00 |
# | alles opruimen en naar huis | 17:30 |
#
# | Pauze 1| 12:45 tot 13:45 |
# | Pauze 2| 15:30 tot 15:55 |

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="foto5.jpeg" alt="schets student 1" width="400"/>

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!

import math

# Natuurkundige constante: permittiviteit van het vacuüm
EPSILON_0 = 8.854187e-12 
epsilon_r=3
def vlakkeplaat(A, d, epsilon_r):
    """
    Berekent de capaciteit van een vlakke plaat condensator.
    Input: 
      A: Oppervlakte van de platen in m^2
      d: Afstand tussen de platen (dikte diëlektricum) in meters
      epsilon_r: Relatieve permittiviteit van het materiaal (default = 1 voor lucht)
    Output: 
      C: Capaciteit in Farad (F)
    """
    # De formule: C = (εr * ε0 * A) / d
    C = (epsilon_r * EPSILON_0 * A) / (d*10**-3)  # d wordt omgezet van micrometer naar meter
    return C

# --- TEST JE CODE HIER ---
# Voorbeeld met jouw papiertje:
oppervlakte = 0.01      # 10cm x 10cm
dikte_papier = 0.0001   # 0.1mm
materiaal = 3.0         # εr voor papier

resultaat = vlakkeplaat(oppervlakte, dikte_papier, materiaal)

print(f"De berekende capaciteit is: {resultaat} Farad")
print(f"In picofarad is dat: {resultaat * 1e12:.2f} pF")

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.
# Out:
# De berekende capaciteit is: 2.6562561e-06 Farad
# In picofarad is dat: 2656256.10 pF

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

import math

# Natuurkundige constante
EPSILON_0 = 8.854187e-12 

def vlakkeplaat(A, d, epsilon_r):
    """Berekent de capaciteit in Farad"""
    C = (epsilon_r * EPSILON_0 * A) / d
    return C

# Jouw specifieke waarden (vul hier jullie eigen A en d in)
A_gemeten = 0.01  # bijv. 10x10 cm
d_gemeten = 0.0015 # bijv. 0.1 mm papier

# Hier vullen we de lijst C met de resultaten van de functie
# We vermenigvuldigen direct met 1e12 om van Farad naar pF te gaan
C = [
    vlakkeplaat(A_gemeten, d_gemeten, 3.0) * 1e12, 
    vlakkeplaat(A_gemeten, d_gemeten, 4.7) * 1e12, 
    vlakkeplaat(A_gemeten, d_gemeten, 1.2) * 1e12
]

# Nu werkt je print-statement perfect
print(f"Berekende capaciteit plaatcondensator groep 6 is {C[0]:.1f} pF")
print(f"Berekende capaciteit plaatcondensator groep 6 is {C[1]:.1f} pF")
print(f"Berekende capaciteit plaatcondensator groep 6 is {C[2]:.1f} pF")
# Out:
# Berekende capaciteit plaatcondensator groep 6 is 177.1 pF
# Berekende capaciteit plaatcondensator groep 6 is 277.4 pF
# Berekende capaciteit plaatcondensator groep 6 is 70.8 pF

# %%
import math

# Constantes (staan vast voor jouw experiment)
R = 1000        # 1k Ohm shunt
VIN_MAX = 8     # 8V amplitude
F = 100000      # 100 kHz
OMEGA = 2 * math.pi * F

def bepaal_C(Vout):
    """
    Vul hier je gemeten Vout in (in Volt).
    De functie geeft de capaciteit terug in Farad.
    """
    # Formule: C = Vout / (R * Vin_max * omega)
    C = Vout / (R * VIN_MAX * OMEGA)
    return C


meting = 0.509 
resultaat = bepaal_C(meting)

print(f"Bij een meting van {meting}V is de capaciteit:")
print(f"{resultaat * 1e12:.1f} pF")
# Out:
# Bij een meting van 0.509V is de capaciteit:
# 101.3 pF

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](foto1.jpeg)
# ![scope meting 2](foto2.jpeg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 6| 177.1 pF|1.78 V | 0.509 V |101.3pF |

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](foto3a.jpeg)

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Pas deze tekst aan: Wij gaan een sensor maken die het gewicht meet.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](foto6.jpeg)

# %%
import math

# Constanten (staan vast voor jouw opstelling)
EPSILON_0 = 8.854187e-12
A = 0.01             # 10x10 cm
R = 1000             # 1k Ohm shunt
VIN_MAX = 8          # 8V amplitude
FREQ = 100000        # 100 kHz
OMEGA = 2 * math.pi * FREQ

def bepaal_epsilon(Vout, d_mm):
    """
    Berekent de relatieve permittiviteit (epsilon) op basis van Vout en de huidige dikte.
    Vout: gemeten spanning in Volt
    d_mm: de dikte van de spons op dat moment in mm
    """
    # 1. Bereken d in meters
    d_m = d_mm / 1000
    
    # 2. Bereken de capaciteit C uit de gemeten Vout
    # C = Vout / (R * Vin_max * omega)
    C = Vout / (R * VIN_MAX * OMEGA)
    
    # 3. Bereken epsilon uit C
    # epsilon_r = (C * d) / (epsilon_0 * A)
    epsilon_r = (C * d_m) / (EPSILON_0 * A)
    
    return epsilon_r, C * 1e12

# --- GEBRUIK ---
# Stel je spons is niet ingedrukt (37.5 mm) en je meet een Vout van 0.6 Volt:
gemeten_Vout = 4.56
huidige_dikte = 37.5

eps, cap = bepaal_epsilon(gemeten_Vout, huidige_dikte)

print(f"Bij een meting van {gemeten_Vout}V en dikte {huidige_dikte}mm:")
print(f"-> Berekende Capaciteit: {cap:.2f} pF")
print(f"-> Berekende Epsilon (eps_r): {eps:.2f}")
# Out:
# Bij een meting van 4.56V en dikte 37.5mm:
# -> Berekende Capaciteit: 907.18 pF
# -> Berekende Epsilon (eps_r): 384.22

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# Constanten
EPSILON_0 = 8.854187e-12
EPS_SPONS = 15      # Relatieve permittiviteit van de spons
A = 0.01            # Oppervlakte (10x10 cm)

# Bereik van de dikte (in meters)
D_START = 0.04    # 37.5 mm
D_EIND = 0.03     # 27.5 mm (dus 1 cm ingedrukt)

def bereken_C(d):
    """Berekent de capaciteit voor een specifieke afstand d"""
    C = (EPS_SPONS * EPSILON_0 * A) / d
    return C * 1e12  # Omgezet naar pF

# Maak een reeks afstanden aan van start naar eind
diktes = np.linspace(D_START, D_EIND, 100)
capaciteiten = [bereken_C(d) for d in diktes]

# --- PLOTTEN ---
plt.figure(figsize=(8, 5))
plt.plot(diktes * 1000, capaciteiten, color='blue', linewidth=2) # x-as in mm

plt.title("Capaciteit vs. Dikte (Traject: 1 cm indrukking)")
plt.xlabel("Dikte van de spons (d) in mm")
plt.ylabel("Capaciteit (C) in pF")
plt.grid(True, alpha=0.3)



plt.show()

# Print de begin- en eindwaarde voor je verslag
print(f"Capaciteit bij {D_START*1000:.2f} mm: {bereken_C(D_START):.2f} pF")
print(f"Capaciteit bij {D_EIND*1000:.2f} mm: {bereken_C(D_EIND):.2f} pF")
print(min(capaciteiten), max(capaciteiten))
# Out:
# Capaciteit bij 40.00 mm: 33.20 pF
# Capaciteit bij 30.00 mm: 44.27 pF
# 33.203201250000006 44.27093500000001

# %%
# deze is puur voor iteratie maar is naturlijk moeilijk om de precieze details van de spons te weten en te modelleren.
import math
import matplotlib.pyplot as plt
import numpy as np

# Constanten
EPSILON_0 = 8.854187e-12
EPS_SPONS = 15      # Relatieve permittiviteit van de spons
A = 0.01            # Oppervlakte (10x10 cm)
D_START = 0.0375     # Beginhoogte spons (35 mm)
K_SPONS = 1500     # Stijfheid van de spons (N/m) 
G = 9.81            # Zwaartekrachtversnelling

def model_gewicht_naar_capaciteit(grammen):
    # 1. Massa naar Newton (F = m * g)
    massa_kg = grammen / 1000
    kracht_N = massa_kg * G
    
    # 2. Kracht naar indrukking (Wet van Hooke: delta_d = F / k)
    indrukking = kracht_N / K_SPONS
    
    # 3. Nieuwe dikte berekenen (met een 'harde stop' op 1mm dikte)
    d_actueel = max(D_START - indrukking, 0.001)
    
    # 4. Capaciteit berekenen (jouw vlakke plaat formule)
    C = (EPS_SPONS * EPSILON_0 * A) / d_actueel
    return C * 1e12 # Resultaat in pF

# --- TESTPLOT: Gewicht vs Capaciteit ---
gewichten = np.linspace(0, 2000, 100) # Van 0 tot 2kg (2000 gram)
capaciteiten = [model_gewicht_naar_capaciteit(g) for g in gewichten]

plt.figure(figsize=(8, 5))
plt.plot(gewichten, capaciteiten, color='green', linewidth=2)
plt.title("Model: Gewicht op spons vs. Capaciteit")
plt.xlabel("Gewicht (gram)")
plt.ylabel("Capaciteit (pF)")
plt.grid(True, alpha=0.3)

# Voorbeeldpuntje printen
print(f"Bij 500 gram is de voorspelde capaciteit: {model_gewicht_naar_capaciteit(500):.1f} pF")

plt.show()
# Out:
# Bij 500 gram is de voorspelde capaciteit: 38.8 pF

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (V)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 907.18 pF | 2.88 |
# | gemiddelde capaciteit| 1072 pF |4.41 |
# | maximale capaciteit| 1237.08 pF |4.81 |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](foto7a.jpeg)
# ![meting 4](foto10.jpeg)
# ![meting 2](foto8a.jpeg)
# ![meting 3](foto9.jpeg)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
from scipy.optimize import curve_fit

# Data invoeren
capaciteit_metingen = np.array([34, 55.2, 37.9, 42.8, 66.5, 61.8, 58.2, 72.5, 79])
gewicht_metingen = np.array([0, 393, 22.2, 111, 750, 596, 465, 1000, 1500])

# Sorteren van de data op gewicht (belangrijk voor een strakke lijn)
indices = np.argsort(gewicht_metingen)
x_data = gewicht_metingen[indices]
y_data = capaciteit_metingen[indices]

# De fit functie
def log_functie(x, a, b, c):
    return a * np.log(x + b) + c

# we schatten startwaarden: 
# b moet groter zijn dan 0 om log(0) te voorkomen bij x=0
p0 = [10, 10, 30] 

# Uitvoeren van de fit
popt, pcov = curve_fit(log_functie, x_data, y_data, p0=p0)


# Plotten
fit_gewicht = np.linspace(0, 1600, 100)
plt.figure(figsize=(10, 6))

plt.plot(x_data, y_data, 'o', label='Gemeten data (pF)')
plt.plot(fit_gewicht, log_functie(fit_gewicht, *popt), 'r--',
         label=f'Fit: {popt[0]:.2f} * ln(x + {popt[1]:.2f}) + {popt[2]:.2f}')

plt.xlabel('Gewicht ($g$)')
plt.ylabel('Capaciteit ($pF$)')
plt.title('Kalibratiegrafiek: Gewicht vs. Capaciteit')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# --- 1. CONSTANTEN EN FUNCTIES ---
EPSILON_0 = 8.854187e-12
EPS_SPONS = 15      # Relatieve permittiviteit van de spons
A = 0.01            # Oppervlakte (10x10 cm)
D_START = 0.0375    # Beginhoogte spons (37.5 mm)
K_SPONS = 1500      # Stijfheid van de spons (N/m) 
G = 9.81            # Zwaartekrachtversnelling

def model_gewicht_naar_capaciteit(grammen):
    """Berekent de theoretische capaciteit op basis van de wet van Hooke."""
    massa_kg = grammen / 1000
    kracht_N = massa_kg * G
    indrukking = kracht_N / K_SPONS
    d_actueel = max(D_START - indrukking, 0.001) # Harde stop op 1mm
    C = (EPS_SPONS * EPSILON_0 * A) / d_actueel
    return C * 1e12 # Teruggeven in pF

def log_functie(x, a, b, c):
    """De functie voor de empirische fit op de meetdata."""
    return a * np.log(x + b) + c

# --- 2. DATA EN FIT VOORBEREIDEN ---
capaciteit_metingen = np.array([34, 55.2, 37.9, 42.8, 66.5, 61.8, 58.2, 72.5, 79])
gewicht_metingen = np.array([0, 393, 22.2, 111, 750, 596, 465, 1000, 1500])

# Sorteren van de data
indices = np.argsort(gewicht_metingen)
x_data = gewicht_metingen[indices]
y_data = capaciteit_metingen[indices]

# Curve fit uitvoeren
p0 = [10, 10, 30] 
popt, pcov = curve_fit(log_functie, x_data, y_data, p0=p0)

# --- 3. PLOTTEN ---
fit_gewicht = np.linspace(0, 1600, 100)

# Bereken de y-waarden voor beide lijnen
y_fit_log = log_functie(fit_gewicht, *popt)
y_model_theorie = [model_gewicht_naar_capaciteit(g) for g in fit_gewicht]

plt.figure(figsize=(10, 7))

# Plot 1: De echte meetpunten
plt.scatter(x_data, y_data, color='black', label='Gemeten data (punten)', zorder=5)

# Plot 2: De logaritmische fit (op basis van metingen)
plt.plot(fit_gewicht, y_fit_log, 'r--', linewidth=2,
         label=f'Log-Fit (Metingen): {popt[0]:.2f}*ln(x+{popt[1]:.2f})+{popt[2]:.2f}')

# Plot 3: Het theoretische model (op basis van Hooke/Capaciteit formule)
plt.plot(fit_gewicht, y_model_theorie, color='green', linewidth=2, 
         label='Theoretisch Model (Hooke + Plaatcondensator)')

# Opmaak
plt.xlabel('Gewicht ($g$)')
plt.ylabel('Capaciteit ($pF$)')
plt.title('Vergelijking: Meetdata & Fit vs. Theoretisch Model')
plt.legend()
plt.grid(True, alpha=0.3)

# Toon de plot
plt.show()

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * verbetering 1 : Een andere spons, waarschijnlijk is deze met een klein beetje water in aanraking gekomen waardoor de Epsilon veel hoger is dan die van een normale spons aangezien de hele structuur dan veel complexer en anders is. Wij kunnen dus door deze spons veel minder nauwkeurig meten aangezien we de epsilon niet op voorhand weten en een schatting moeten maken
# * verbetering 2
# Een mechanisme of beugel waar de object stabiel op kan staan. Tijdens de metingen waren de voorwerpen soms scheef op de platen tussen de spons, waardoor er afwijkende metingen van de capicteit was. Dit was voraal het gevaal bij zwaardere gewichten, waarmee de voorwerp soms omviel, of dus scheef stond

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](foto11.jpeg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# --- DEEL 1: KALIBRATIE (LOG FIT) ---
capaciteit_metingen = np.array([34, 55.2, 37.9, 42.8, 66.5, 61.8, 58.2, 72.5, 79])
gewicht_metingen = np.array([0, 393, 22.2, 111, 750, 596, 465, 1000, 1500])

indices = np.argsort(gewicht_metingen)
x_data = gewicht_metingen[indices]
y_data = capaciteit_metingen[indices]

def log_functie(x, a, b, c):
    return a * np.log(x + b) + c

p0 = [10, 10, 30] 
popt, pcov = curve_fit(log_functie, x_data, y_data, p0=p0)

plt.figure(figsize=(10, 6))
fit_gewicht = np.linspace(0, 1500, 100)
plt.plot(x_data, y_data, 'o', label='Gemeten data (pF)')
plt.plot(fit_gewicht, log_functie(fit_gewicht, *popt), 'r--',
         label=f'Fit: {popt[0]:.2f} * ln(x + {popt[1]:.2f}) + {popt[2]:.2f}')
plt.xlabel('Gewicht (g)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek: Gewicht vs. Capaciteit')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# --- DEEL 2: THEORETISCH MODEL (CAPACITEIT VS DIKTE) ---
EPSILON_0 = 8.854187e-12
EPS_SPONS = 15      
A = 0.01            

D_START = 0.04    # 40 mm (niet ingedrukt)
D_EIND = 0.03     # 30 mm (1 cm ingedrukt)

def bereken_C(d):
    """Berekent de capaciteit voor een specifieke afstand d"""
    C = (EPS_SPONS * EPSILON_0 * A) / d
    return C * 1e12  # Naar pF

# Hier maken we de reeks van KLEIN (30mm) naar GROOT (40mm)
diktes = np.linspace(D_EIND, D_START, 100)
capaciteiten = [bereken_C(d) for d in diktes]

plt.figure(figsize=(8, 5))
plt.plot(diktes * 1000, capaciteiten, color='blue', linewidth=2) 

plt.title("Capaciteit vs. Dikte (Toenemend op x-as)")
plt.xlabel("Dikte van de spons (d) in mm")
plt.ylabel("Capaciteit (C) in pF")
plt.grid(True, alpha=0.3)

# LET OP: plt.gca().invert_xaxis() is hier weggehaald!

plt.show()

# Output voor verslag
print(f"Capaciteit bij {D_EIND*1000:.2f} mm: {bereken_C(D_EIND):.2f} pF")
print(f"Capaciteit bij {D_START*1000:.2f} mm: {bereken_C(D_START):.2f} pF")
# Out:
# Capaciteit bij 30.00 mm: 44.27 pF
# Capaciteit bij 40.00 mm: 33.20 pF

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# Ons vooraf bepaalde model komt helaas totaal niet overeen met de metingen. Dit kan komen doordat ons model niet meeneemt dat er een exponentieel verband zit tussen het gewicht en de indeuking. Ook is de spons waarschijnlijk in contact geweest met een beetje water, waardoor het dieelektrische medium ook helemaal verstoord is. En de epsilon niet goed bepaald kan worden door de hele complexe structuur die die daardoor heeft. Om ons model te verbeteren zouden we natuurlijk dat exponentiele verband moeten meenemen, zorgen dat we een goeie spons hebben en zorgen dat die er stabiel boven blijft

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!

import math

# Natuurkundige constante: permittiviteit van het vacuüm
EPSILON_0 = 8.854187e-12 
epsilon_r=3
def vlakkeplaat(A, d, epsilon_r):
    """
    Berekent de capaciteit van een vlakke plaat condensator.
    Input: 
      A: Oppervlakte van de platen in m^2
      d: Afstand tussen de platen (dikte diëlektricum) in meters
      epsilon_r: Relatieve permittiviteit van het materiaal (default = 1 voor lucht)
    Output: 
      C: Capaciteit in Farad (F)
    """
    # De formule: C = (εr * ε0 * A) / d
    C = (epsilon_r * EPSILON_0 * A) / (d*10**-3)  # d wordt omgezet van micrometer naar meter
    return C

# --- TEST JE CODE HIER ---
# Voorbeeld met jouw papiertje:
oppervlakte = 0.01      # 10cm x 10cm
dikte_papier = 0.0001   # 0.1mm
materiaal = 3.0         # εr voor papier

resultaat = vlakkeplaat(oppervlakte, dikte_papier, materiaal)

print(f"De berekende capaciteit is: {resultaat} Farad")
print(f"In picofarad is dat: {resultaat * 1e12:.2f} pF")

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.
# Out:
# De berekende capaciteit is: 2.6562561e-06 Farad
# In picofarad is dat: 2656256.10 pF

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

import math

# Natuurkundige constante
EPSILON_0 = 8.854187e-12 

def vlakkeplaat(A, d, epsilon_r):
    """Berekent de capaciteit in Farad"""
    C = (epsilon_r * EPSILON_0 * A) / d
    return C

# Jouw specifieke waarden (vul hier jullie eigen A en d in)
A_gemeten = 0.01  # bijv. 10x10 cm
d_gemeten = 0.0015 # bijv. 0.1 mm papier

# Hier vullen we de lijst C met de resultaten van de functie
# We vermenigvuldigen direct met 1e12 om van Farad naar pF te gaan
C = [
    vlakkeplaat(A_gemeten, d_gemeten, 3.0) * 1e12, 
    vlakkeplaat(A_gemeten, d_gemeten, 4.7) * 1e12, 
    vlakkeplaat(A_gemeten, d_gemeten, 1.2) * 1e12
]

# Nu werkt je print-statement perfect
print(f"Berekende capaciteit plaatcondensator groep 6 is {C[0]:.1f} pF")
print(f"Berekende capaciteit plaatcondensator groep 6 is {C[1]:.1f} pF")
print(f"Berekende capaciteit plaatcondensator groep 6 is {C[2]:.1f} pF")
# Out:
# Berekende capaciteit plaatcondensator groep 6 is 177.1 pF
# Berekende capaciteit plaatcondensator groep 6 is 277.4 pF
# Berekende capaciteit plaatcondensator groep 6 is 70.8 pF

# %%
# deze is puur voor iteratie maar is naturlijk moeilijk om de precieze details van de spons te weten en te modelleren.
import math
import matplotlib.pyplot as plt
import numpy as np

# Constanten
EPSILON_0 = 8.854187e-12
EPS_SPONS = 15      # Relatieve permittiviteit van de spons
A = 0.01            # Oppervlakte (10x10 cm)
D_START = 0.0375     # Beginhoogte spons (35 mm)
K_SPONS = 1500     # Stijfheid van de spons (N/m) 
G = 9.81            # Zwaartekrachtversnelling

def model_gewicht_naar_capaciteit(grammen):
    # 1. Massa naar Newton (F = m * g)
    massa_kg = grammen / 1000
    kracht_N = massa_kg * G
    
    # 2. Kracht naar indrukking (Wet van Hooke: delta_d = F / k)
    indrukking = kracht_N / K_SPONS
    
    # 3. Nieuwe dikte berekenen (met een 'harde stop' op 1mm dikte)
    d_actueel = max(D_START - indrukking, 0.001)
    
    # 4. Capaciteit berekenen (jouw vlakke plaat formule)
    C = (EPS_SPONS * EPSILON_0 * A) / d_actueel
    return C * 1e12 # Resultaat in pF

# --- TESTPLOT: Gewicht vs Capaciteit ---
gewichten = np.linspace(0, 2000, 100) # Van 0 tot 2kg (2000 gram)
capaciteiten = [model_gewicht_naar_capaciteit(g) for g in gewichten]

plt.figure(figsize=(8, 5))
plt.plot(gewichten, capaciteiten, color='green', linewidth=2)
plt.title("Model: Gewicht op spons vs. Capaciteit")
plt.xlabel("Gewicht (gram)")
plt.ylabel("Capaciteit (pF)")
plt.grid(True, alpha=0.3)

# Voorbeeldpuntje printen
print(f"Bij 500 gram is de voorspelde capaciteit: {model_gewicht_naar_capaciteit(500):.1f} pF")

plt.show()
# Out:
# Bij 500 gram is de voorspelde capaciteit: 38.8 pF

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](foto1.jpeg)
# ![scope meting 2](foto2.jpeg)

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](foto6.jpeg)

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# --- 1. CONSTANTEN EN FUNCTIES ---
EPSILON_0 = 8.854187e-12
EPS_SPONS = 15      # Relatieve permittiviteit van de spons
A = 0.01            # Oppervlakte (10x10 cm)
D_START = 0.0375    # Beginhoogte spons (37.5 mm)
K_SPONS = 1500      # Stijfheid van de spons (N/m) 
G = 9.81            # Zwaartekrachtversnelling

def model_gewicht_naar_capaciteit(grammen):
    """Berekent de theoretische capaciteit op basis van de wet van Hooke."""
    massa_kg = grammen / 1000
    kracht_N = massa_kg * G
    indrukking = kracht_N / K_SPONS
    d_actueel = max(D_START - indrukking, 0.001) # Harde stop op 1mm
    C = (EPS_SPONS * EPSILON_0 * A) / d_actueel
    return C * 1e12 # Teruggeven in pF

def log_functie(x, a, b, c):
    """De functie voor de empirische fit op de meetdata."""
    return a * np.log(x + b) + c

# --- 2. DATA EN FIT VOORBEREIDEN ---
capaciteit_metingen = np.array([34, 55.2, 37.9, 42.8, 66.5, 61.8, 58.2, 72.5, 79])
gewicht_metingen = np.array([0, 393, 22.2, 111, 750, 596, 465, 1000, 1500])

# Sorteren van de data
indices = np.argsort(gewicht_metingen)
x_data = gewicht_metingen[indices]
y_data = capaciteit_metingen[indices]

# Curve fit uitvoeren
p0 = [10, 10, 30] 
popt, pcov = curve_fit(log_functie, x_data, y_data, p0=p0)

# --- 3. PLOTTEN ---
fit_gewicht = np.linspace(0, 1600, 100)

# Bereken de y-waarden voor beide lijnen
y_fit_log = log_functie(fit_gewicht, *popt)
y_model_theorie = [model_gewicht_naar_capaciteit(g) for g in fit_gewicht]

plt.figure(figsize=(10, 7))

# Plot 1: De echte meetpunten
plt.scatter(x_data, y_data, color='black', label='Gemeten data (punten)', zorder=5)

# Plot 2: De logaritmische fit (op basis van metingen)
plt.plot(fit_gewicht, y_fit_log, 'r--', linewidth=2,
         label=f'Log-Fit (Metingen): {popt[0]:.2f}*ln(x+{popt[1]:.2f})+{popt[2]:.2f}')

# Plot 3: Het theoretische model (op basis van Hooke/Capaciteit formule)
plt.plot(fit_gewicht, y_model_theorie, color='green', linewidth=2, 
         label='Theoretisch Model (Hooke + Plaatcondensator)')

# Opmaak
plt.xlabel('Gewicht ($g$)')
plt.ylabel('Capaciteit ($pF$)')
plt.title('Vergelijking: Meetdata & Fit vs. Theoretisch Model')
plt.legend()
plt.grid(True, alpha=0.3)

# Toon de plot
plt.show()

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# Ons vooraf bepaalde model komt helaas totaal niet overeen met de metingen. Dit kan komen doordat ons model niet meeneemt dat er een exponentieel verband zit tussen het gewicht en de indeuking. Ook is de spons waarschijnlijk in contact geweest met een beetje water, waardoor het dieelektrische medium ook helemaal verstoord is. En de epsilon niet goed bepaald kan worden door de hele complexe structuur die die daardoor heeft. Om ons model te verbeteren zouden we natuurlijk dat exponentiele verband moeten meenemen, zorgen dat we een goeie spons hebben en zorgen dat die er stabiel boven blijft
